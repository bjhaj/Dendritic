# %% [markdown]
# <a href="https://colab.research.google.com/github/bjhaj/Dendritic/blob/main/Dendritic_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone "https://github.com/bjhaj/Dendritic/"
# Out:
# Cloning into 'Dendritic'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 49 (delta 7), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (49/49), 14.30 KiB | 4.77 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd Dendritic
# Out:
# /content/Dendritic

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 32.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.3/137.3 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for inplace_abn: filename=inplace_abn-1.1.0-cp310-cp310-linux_x86_64.whl size=4158270 sha256=ce456b4ea609855808d158aff870c045328778f17f8a474897d7818d22d187ba
#   Stored in directory: /root/.cache/pip/wheels/c7/f2/05/97ab74dbf2ed6d592684f76d0ae8f33f66bbafa0ec5b53b416
# Successfully built inplace_abn
# ...

# %%
# !gdown --folder https://drive.google.com/drive/folders/13fi2c26jC9bgEhUhBvfG8nAqOZridZEp?usp=drive_link
# Out:
# Retrieving folder list
# Processing file 18PW-555Goxt3qMehySBOch6P6wDTO9co Dend.zip
# Processing file 1fWEhRkLmtn-WBNXEKm1RNwwNfOAZVezz fing_model
# Processing file 19qL7Z1bwVB6O3qVkal1Mb5LHAWSEigCV fingdata_pytorch.zip
# Processing file 1knV_xaOM0EuSKoiPPwFu3z6nx-YiCkEj resnet50_miil_21k.pth
# Processing file 1RhYVmgSvpSP4-YUoEMy9cZJrePkZCmnP resnet50imagenet1k.pth
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=18PW-555Goxt3qMehySBOch6P6wDTO9co
# To: /content/Dendritic/remote_dendrite_access/Dend.zip
# 100% 142M/142M [00:03<00:00, 42.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fWEhRkLmtn-WBNXEKm1RNwwNfOAZVezz
# To: /content/Dendritic/remote_dendrite_access/fing_model
# 100% 94.4M/94.4M [00:01<00:00, 53.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=19qL7Z1bwVB6O3qVkal1Mb5LHAWSEigCV
# ...

# %%
# !unzip '/content/Dendritic/remote_dendrite_access/Dend.zip'
# Out:
# Archive:  /content/Dendritic/remote_dendrite_access/Dend.zip
#    creating: Dend/
#   inflating: __MACOSX/._Dend
#   inflating: Dend/.DS_Store
#   inflating: __MACOSX/Dend/._.DS_Store
#    creating: Dend/Dend10/
#   inflating: __MACOSX/Dend/._Dend10
#    creating: Dend/Dend9/
#   inflating: __MACOSX/Dend/._Dend9
#    creating: Dend/Dend7/
#   inflating: __MACOSX/Dend/._Dend7
#    creating: Dend/Dend6/
#   inflating: __MACOSX/Dend/._Dend6
#    creating: Dend/Dend1/
#   inflating: __MACOSX/Dend/._Dend1
#    creating: Dend/Dend8/
#   inflating: __MACOSX/Dend/._Dend8
#    creating: Dend/Dend4/
#   inflating: __MACOSX/Dend/._Dend4
#    creating: Dend/Dend3/
#   inflating: __MACOSX/Dend/._Dend3
#    creating: Dend/Dend2/
#   inflating: __MACOSX/Dend/._Dend2
#    creating: Dend/Dend5/
#   inflating: __MACOSX/Dend/._Dend5
#   inflating: Dend/Dend10/Screen Shot 2023-02-06 at 11.41.09 AM.png
#   inflating: __MACOSX/Dend/Dend10/._Screen Shot 2023-02-06 at 11.41.09 AM.png
# ...

# %%
import splitfolders
def create_split(train, val):
  splitfolders.ratio('/content/Dendritic/Dend', # The location of dataset
                    output="/content/newtraindata", # The output location
                    seed=42, # The number of seed
                    ratio=(train, val), # The ratio of splited dataset
                    group_prefix=None, # If your dataset contains more than one file like ".jpg", ".pdf", etc
                    move=False # If you choose to move, turn this into True
                    )

# %%
create_split(0.8,0.2)
# Out:
# Copying files: 262 files [00:00, 1408.09 files/s]

# %%
# %matplotlib inline
import argparse
import time
import torch
import torch.nn.parallel
import torch.optim
import torch.utils.data.distributed
from torch.optim import lr_scheduler
import numpy as np
import matplotlib.pyplot as plt


# %run train.py --model_path /content/Dendritic/remote_dendrite_access/resnet50_miil_21k.pth --epochs 200
# Out:
# creating model resnet50...
# could not load layer: fc.weight, mismatch shape torch.Size([10, 2048]) ,torch.Size([11221, 2048])
# could not load layer: fc.bias, mismatch shape torch.Size([10]) ,torch.Size([11221])
# done
#
# length train dataset: 207
# length val dataset: 55
#
# Epoch 0
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch: 1/200, Training Loss: 2.3219
#
# Finished Epoch, Training Rate: 43.2 [img/sec]
# starting validation
# Validation results:
# Acc_Top1 [%] 10.91,  Acc_Top5 [%] 50.91
#
# Epoch 1
# Epoch: 2/200, Training Loss: 2.3186
#
# ...

# %%
# %run train.py --model_name resnet50 --epochs 200
# Out:
# creating model resnet50...
# done
#
# length train dataset: 207
# length val dataset: 55
#
# Epoch 0
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch: 1/200, Training Loss: 2.3109
#
# Finished Epoch, Training Rate: 102.6 [img/sec]
# starting validation
# Validation results:
# Acc_Top1 [%] 9.09,  Acc_Top5 [%] 49.09
#
# Epoch 1
# Epoch: 2/200, Training Loss: 2.3029
#
# Finished Epoch, Training Rate: 100.1 [img/sec]
# starting validation
# Validation results:
# Acc_Top1 [%] 9.09,  Acc_Top5 [%] 49.09
#
# Epoch 2
# Epoch: 3/200, Training Loss: 2.3109
#
# ...
